# %%
import pandas as pd
from scipy import stats
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
ramen_ratings = pd.read_csv("ramen-ratings.csv")
ramen_ratings.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
# Remove the rows with missing data
clean_ramen = ramen_ratings.dropna(how="any")
clean_ramen.count()
# Out:
# Review #    41
# Brand       41
# Variety     41
# Style       41
# Country     41
# Stars       41
# Top Ten     41
# dtype: int64

# %%
ramen_ratings['Brand'].count
# Out:
# <bound method Series.count of 0            New Touch
# 1             Just Way
# 2               Nissin
# 3              Wei Lih
# 4       Ching's Secret
#              ...
# 2575             Vifon
# 2576           Wai Wai
# 2577           Wai Wai
# 2578           Wai Wai
# 2579          Westbrae
# Name: Brand, Length: 2580, dtype: object>

# %%
ramen_ratings['Brand'].agg
# Out:
# <bound method Series.aggregate of 0            New Touch
# 1             Just Way
# 2               Nissin
# 3              Wei Lih
# 4       Ching's Secret
#              ...
# 2575             Vifon
# 2576           Wai Wai
# 2577           Wai Wai
# 2578           Wai Wai
# 2579          Westbrae
# Name: Brand, Length: 2580, dtype: object>

# %%
ramen_ratings.loc['Ratings'] :10

# %%
clean_ramen .sort_values('Stars', ascending=False)
# Out:
#       Review #             Brand  \
# 616       1964              MAMA
# 1757       823             Paldo
# 1382      1198     Samyang Foods
# 633       1947       Prima Taste
# 1493      1087           MyKuali
# 1588       992       Prima Taste
# 1589       991       Prima Taste
# 1646       934          Nongshim
# 1846       734           Indomie
# 1278      1302              Mama
# 1865       715           Indomie
# 1972       608              Koka
# 2188       392            Nissin
# 2475       105           Indomie
# 2533        47           Indomie
# 2535        45           Indomie
# 1309      1271       Prima Taste
# 1397      1183             Paldo
# 1272      1308          Nongshim
# 995       1585            CarJEN
# 655       1925             Prima
# 673       1907       Prima Taste
# 752       1828     Tseng Noodles
# 891       1689      Wugudaochang
# 1250      1330   Sapporo Ichiban
# 963       1617           MyKuali
# 942       1638  A-Sha Dry Noodle
# ...

# %%
#US brands

Japan_ramen = clean_ramen.loc[clean_ramen ["Country"] == "Japan", :]
Japan_ramen.head()
# Out:
#       Review #            Brand                          Variety Style  \
# 1059      1521         Maruchan         Gotsumori Sauce Yakisoba  Tray
# 1250      1330  Sapporo Ichiban   Otafuku Okonomi Sauce Yakisoba  Tray
# 2188       392           Nissin         Yakisoba Noodles Karashi  Tray
# 2189       391            Myojo  Hyoubanya No Chukasoba Oriental  Pack
# 2549        31            Myojo               Ippeichan Yakisoba  Tray
#
#      Country Stars  Top Ten
# 1059   Japan     5  2015 #9
# 1250   Japan     5  2014 #4
# 2188   Japan     5  2012 #3
# 2189   Japan  4.25  2012 #6
# 2549   Japan     4  2013 #6

# %%
# Sort based upon multiple columns
Brand = Japan_ramen.sort_values(["Stars", "Brand"])
Brand.head()
# Out:
#       Review #            Brand                          Variety Style  \
# 2549        31            Myojo               Ippeichan Yakisoba  Tray
# 2189       391            Myojo  Hyoubanya No Chukasoba Oriental  Pack
# 1059      1521         Maruchan         Gotsumori Sauce Yakisoba  Tray
# 2188       392           Nissin         Yakisoba Noodles Karashi  Tray
# 1250      1330  Sapporo Ichiban   Otafuku Okonomi Sauce Yakisoba  Tray
#
#      Country Stars  Top Ten
# 2549   Japan     4  2013 #6
# 2189   Japan  4.25  2012 #6
# 1059   Japan     5  2015 #9
# 2188   Japan     5  2012 #3
# 1250   Japan     5  2014 #4

# %%
new_index = Japan_ramen.reset_index(drop = True)
new_index.head()
# Out:
#    Review #            Brand                          Variety Style Country  \
# 0      1521         Maruchan         Gotsumori Sauce Yakisoba  Tray   Japan
# 1      1330  Sapporo Ichiban   Otafuku Okonomi Sauce Yakisoba  Tray   Japan
# 2       392           Nissin         Yakisoba Noodles Karashi  Tray   Japan
# 3       391            Myojo  Hyoubanya No Chukasoba Oriental  Pack   Japan
# 4        31            Myojo               Ippeichan Yakisoba  Tray   Japan
#
#   Stars  Top Ten
# 0     5  2015 #9
# 1     5  2014 #4
# 2     5  2012 #3
# 3  4.25  2012 #6
# 4     4  2013 #6

# %%
#Breaki into bins by rating 
Japan_ramen = Japan_ramen.fillna("")
bins = [0,1.9,2.9,3.9,4.9,5.9]

groups = ["1","2","3","4","5"]

Japan_ramen['Ranking'] = pd.cut(Japan_ramen["Stars"], bins, labels=groups, include_lowest=True)
Japan_ramen
#ratings_binned.head()
#pd.cut(df["Test Score"], bins, labels=group_names, include_lowest=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-afaefd88f3f2> in <module>
#       5 groups = ["1","2","3","4","5"]
#       6
# ----> 7 Japan_ramen['Ranking'] = pd.cut(Japan_ramen["Stars"], bins, labels=groups, include_lowest=True)
#       8 Japan_ramen
#       9 #ratings_binned.head()
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     263         include_lowest=include_lowest,
#     264         dtype=dtype,
# --> 265         duplicates=duplicates,
#     266     )
#     267
#
# ~\.conda\envs\PythonData\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     386
#     387     side = "left" if right else "right"
# ...

# %%
##What is the top seeling brand by country? 
##By style?
